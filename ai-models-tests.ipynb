# %%
import requests
API_TOKEN = "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"
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/tiiuae/falcon-7b-instruct"
def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": "What is 2 + 2*2?" })
print(output)
# Out:
# [{'generated_text': 'What is 2 + 2*2?\n2 + 2*2 = 6'}]

# %%
from pprint import pprint
import requests
API_TOKEN = "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"
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/tiiuae/falcon-7b-instruct"
def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": """I will provide you with outputs from smart contract frameworks Securify, SmartCheck, Slither and Solhint. Based on the outputs from given contracts, group th
e common errors among the contracts by meaning and context and return in JSON format as a result {error_name: list_of_frameworks_names} eg. {Incorect solidity version: [solhint, smartcheck], function call w
ithout data: [slither],}. Take into considerations errors from every framework. Errors should be in human readable form. Sometimes errors have different names but mean the same, handle it, especially smartc
heck - try to rename them. Frameworks are separated by the "START" and "END" keywords. START securify: Framework doesn\'t work END, START solhint: A new version of Solhint is available: 4.1.1\nPlease consid
er updating your Solhint package.\n\ncontracts/calls.sol\n   1:1  error    Compiler version must be declared                                                          compiler-version\n   3:2  warning  Varia
ble name must be in mixedCase                                                         var-name-mixedcase\n   4:2  warning  Variable name must be in mixedCase                                                         var-name-mixedcase\n   6:2  warning  Explicitly mark visibility of state                                                        state-visibility\n   6:2  warning  \'statevar\' should start with _                                                             private-vars-leading-underscore\n   8:2  warning  Constructor keyword not available before 0.4.22 (undefined)                                constructor-syntax\n   8:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  12:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  13:6  warning  Avoid to use low level calls                                                               avoid-low-level-calls\n  16:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  17:6  warning  Avoid to use low level calls                                                               avoid-low-level-calls\n  21:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  22:6  warning  Avoid to use low level calls                                                               avoid-low-level-calls\n  25:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  26:6  warning  Avoid to use low level calls                                                               avoid-low-level-calls\n  29:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n\n✖ 16 problems (1 error, 15 warnings)\n\n END, START slither: \'solc --version\' running\n\'solc contracts/calls.sol --combined-json abi,ast,bin,bin-runtime,srcmap,srcmap-runtime,userdoc,devdoc,hashes,compact-format --allow-paths .,/src/contracts\' running\nCompilation warnings/errors on contracts/calls.sol:\nWarning: SPDX license identifier not provided in source file. Before publishing, consider adding a comment containing "SPDX-License-Identifier: <SPDX-License>" to each source file. Use "SPDX-License-Identifier: UNLICENSED" for non-open-source code. Please see https://spdx.org for more information.\n--> contracts/calls.sol\n\nWarning: Source file does not specify required compiler version! Consider adding "pragma solidity ^0.8.2;"\n--> contracts/calls.sol\n\nWarning: Visibility for constructor is ignored. If you want the contract to be non-deployable, making it "abstract" is sufficient.\n --> contracts/calls.sol:8:2:\n  |\n8 | \tconstructor(address addr) public {\n  | \t^ (Relevant source part starts here and spans across multiple lines).\n\nWarning: Return value of low-level calls not used.\n  --> contracts/calls.sol:13:6:\n   |\n13 | \t    fixed_address.call("");\n   | \t    ^^^^^^^^^^^^^^^^^^^^^^\n\nWarning: Return value of low-level calls not used.\n  --> contracts/calls.sol:17:6:\n   |\n17 | \t    fixed_address.call("");\n   | \t    ^^^^^^^^^^^^^^^^^^^^^^\n\nWarning: Return value of low-level calls not used.\n  --> contracts/calls.sol:22:6:\n   |\n22 | \t    addr.call("");\n   | \t    ^^^^^^^^^^^^^\n\nWarning: Return value of low-level calls not used.\n  --> contracts/calls.sol:26:6:\n   |\n26 | \t    stored_address.call("");\n   | \t    ^^^^^^^^^^^^^^^^^^^^^^^\n\n\nINFO:Detectors:\nCaller.thisisfine() (contracts/calls.sol#12-14) ignores return value by fixed_address.call() (contracts/calls.sol#13)\nCaller.reentrancy() (contracts/calls.sol#16-19) ignores return value by fixed_address.call() (contracts/calls.sol#17)\nCaller.calluseraddress(address) (contracts/calls.sol#21-23) ignores return value by addr.call() (contracts/calls.sol#22)\nCaller.callstoredaddress() (contracts/calls.sol#25-27) ignores return value by stored_address.call() (contracts/calls.sol#26)\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#unchecked-low-level-calls\nINFO:Detectors:\nCaller.constructor(address).addr (contracts/calls.sol#8) lacks a zero-check on :\n\t\t- fixed_address = addr (contracts/calls.sol#9)\nCaller.calluseraddress(address).addr (contracts/calls.sol#21) lacks a zero-check on :\n\t\t- addr.call() (contracts/calls.sol#22)\nCaller.setstoredaddress(address).addr (contracts/calls.sol#29) lacks a zero-check on :\n\t\t- stored_address = addr (contracts/calls.sol#30)\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#missing-zero-address-validation\nINFO:Detectors:\nReentrancy in Caller.reentrancy() (contracts/calls.sol#16-19):\n\tExternal calls:\n\t- fixed_address.call() (contracts/calls.sol#17)\n\tState variables written after the call(s):\n\t- statevar = 0 (contracts/calls.sol#18)\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#reentrancy-vulnerabilities-2\nINFO:Detectors:\nsolc-0.8.2 is not recommended for deployment\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#incorrect-versions-of-solidity\nINFO:Detectors:\nLow level call in Caller.thisisfine() (contracts/calls.sol#12-14):\n\t- fixed_address.call() (contracts/calls.sol#13)\nLow level call in Caller.reentrancy() (contracts/calls.sol#16-19):\n\t- fixed_address.call() (contracts/calls.sol#17)\nLow level call in Caller.calluseraddress(address) (contracts/calls.sol#21-23):\n\t- addr.call() (contracts/calls.sol#22)\nLow level call in Caller.callstoredaddress() (contracts/calls.sol#25-27):\n\t- stored_address.call() (contracts/calls.sol#26)\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#low-level-calls\nINFO:Detectors:\nVariable Caller.fixed_address (contracts/calls.sol#3) is not in mixedCase\nVariable Caller.stored_address (contracts/calls.sol#4) is not in mixedCase\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#conformance-to-solidity-naming-conventions\nINFO:Detectors:\nCaller.fixed_address (contracts/calls.sol#3) should be immutable \nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#state-variables-that-could-be-declared-immutable\nINFO:Slither:contracts/calls.sol analyzed (1 contracts with 93 detectors), 16 result(s) found\n END, smartcheck: \nruleId: SOLIDITY_CALL_WITHOUT_DATA\npatternId: 111ppp\nseverity: 2\nline: 17\ncolumn: 19\ncontent: call("")\n\nruleId: SOLIDITY_CALL_WITHOUT_DATA\npatternId: 111ppp\nseverity: 2\nline: 22\ncolumn: 10\ncontent: call("")\n\nruleId: SOLIDITY_CALL_WITHOUT_DATA\npatternId: 111ppp\nseverity: 2\nline: 26\ncolumn: 20\ncontent: call("")\n\nruleId: SOLIDITY_UNCHECKED_CALL\npatternId: f39eed\nseverity: 3\nline: 13\ncolumn: 19\ncontent: call("")\n\nruleId: SOLIDITY_UNCHECKED_CALL\npatternId: f39eed\nseverity: 3\nline: 17\ncolumn: 19\ncontent: call("")\n\nruleId: SOLIDITY_UNCHECKED_CALL\npatternId: f39eed\nseverity: 3\nline: 22\ncolumn: 10\ncontent: call("")\n\nruleId: SOLIDITY_UNCHECKED_CALL\npatternId: f39eed\nseverity: 3\nline: 26\ncolumn: 20\ncontent: call("")\n\nruleId: SOLIDITY_VISIBILITY\npatternId: b51ce0\nseverity: 1\nline: 6\ncolumn: 1\ncontent: uint256statevar;\n\nSOLIDITY_VISIBILITY :1\nSOLIDITY_UNCHECKED_CALL :4\nSOLIDITY_CALL_WITHOUT_DATA :4\n END, SOLIDITY_UNCHECKED_CALL :4\n\nThe following code is a comprehensive list of Solidity compiler warnings and errors that are commonly found in Solidity codebase.\n\n1. Solidity compiler warnings and errors are usually caused by incorrect syntax or incorrect Solidity compiler version.\n\n2. Solidity compiler warnings and errors are usually caused by incorrect Solidity compiler version.\n\n3. Solidity compiler warnings and errors are usually caused by incorrect Solidity compiler",
"""})
pprint(output)
# Out:
# [{'generated_text': 'I will provide you with outputs from smart contract '
#                     'frameworks Securify, SmartCheck, Slither and Solhint. '
#                     'Based on the outputs from given contracts, group th\n'
#                     'e common errors among the contracts by meaning and '
#                     'context and return in JSON format as a result '
#                     '{error_name: list_of_frameworks_names} eg. {Incorect '
#                     'solidity version: [solhint, smartcheck], function call w\n'
#                     'ithout data: [slither],}. Take into considerations errors '
#                     'from every framework. Errors should be in human readable '
#                     'form. Sometimes errors have different names but mean the '
#                     'same, handle it, especially smartc\n'
#                     'heck - try to rename them. Frameworks are separated by '
# ...

# %%
from pprint import pprint
import requests
API_TOKEN = "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"
headers = {"Authorization": f"Bearer {API_TOKEN}"}
API_URL = "https://api-inference.huggingface.co/models/bigscience/bloom-560m"
def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()
	
output = query({
	"inputs": """I will provide you with outputs from smart contract frameworks Securify, SmartCheck, Slither and Solhint. Based on the outputs from given contracts, group th
e common errors among the contracts by meaning and context and return in JSON format as a result {error_name: list_of_frameworks_names} eg. {Incorect solidity version: [solhint, smartcheck], function call w
ithout data: [slither],}. Take into considerations errors from every framework. Errors should be in human readable form. Sometimes errors have different names but mean the same, handle it, especially smartc
heck - try to rename them. Frameworks are separated by the "START" and "END" keywords. START securify: Framework doesn\'t work END, START solhint: A new version of Solhint is available: 4.1.1\nPlease consid
er updating your Solhint package.\n\ncontracts/calls.sol\n   1:1  error    Compiler version must be declared                                                          compiler-version\n   3:2  warning  Varia
ble name must be in mixedCase                                                         var-name-mixedcase\n   4:2  warning  Variable name must be in mixedCase                                                         var-name-mixedcase\n   6:2  warning  Explicitly mark visibility of state                                                        state-visibility\n   6:2  warning  \'statevar\' should start with _                                                             private-vars-leading-underscore\n   8:2  warning  Constructor keyword not available before 0.4.22 (undefined)                                constructor-syntax\n   8:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  12:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  13:6  warning  Avoid to use low level calls                                                               avoid-low-level-calls\n  16:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  17:6  warning  Avoid to use low level calls                                                               avoid-low-level-calls\n  21:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  22:6  warning  Avoid to use low level calls                                                               avoid-low-level-calls\n  25:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n  26:6  warning  Avoid to use low level calls                                                               avoid-low-level-calls\n  29:2  warning  All public or external methods in a contract must override a definition from an interface  comprehensive-interface\n\n✖ 16 problems (1 error, 15 warnings)\n\n END, START slither: \'solc --version\' running\n\'solc contracts/calls.sol --combined-json abi,ast,bin,bin-runtime,srcmap,srcmap-runtime,userdoc,devdoc,hashes,compact-format --allow-paths .,/src/contracts\' running\nCompilation warnings/errors on contracts/calls.sol:\nWarning: SPDX license identifier not provided in source file. Before publishing, consider adding a comment containing "SPDX-License-Identifier: <SPDX-License>" to each source file. Use "SPDX-License-Identifier: UNLICENSED" for non-open-source code. Please see https://spdx.org for more information.\n--> contracts/calls.sol\n\nWarning: Source file does not specify required compiler version! Consider adding "pragma solidity ^0.8.2;"\n--> contracts/calls.sol\n\nWarning: Visibility for constructor is ignored. If you want the contract to be non-deployable, making it "abstract" is sufficient.\n --> contracts/calls.sol:8:2:\n  |\n8 | \tconstructor(address addr) public {\n  | \t^ (Relevant source part starts here and spans across multiple lines).\n\nWarning: Return value of low-level calls not used.\n  --> contracts/calls.sol:13:6:\n   |\n13 | \t    fixed_address.call("");\n   | \t    ^^^^^^^^^^^^^^^^^^^^^^\n\nWarning: Return value of low-level calls not used.\n  --> contracts/calls.sol:17:6:\n   |\n17 | \t    fixed_address.call("");\n   | \t    ^^^^^^^^^^^^^^^^^^^^^^\n\nWarning: Return value of low-level calls not used.\n  --> contracts/calls.sol:22:6:\n   |\n22 | \t    addr.call("");\n   | \t    ^^^^^^^^^^^^^\n\nWarning: Return value of low-level calls not used.\n  --> contracts/calls.sol:26:6:\n   |\n26 | \t    stored_address.call("");\n   | \t    ^^^^^^^^^^^^^^^^^^^^^^^\n\n\nINFO:Detectors:\nCaller.thisisfine() (contracts/calls.sol#12-14) ignores return value by fixed_address.call() (contracts/calls.sol#13)\nCaller.reentrancy() (contracts/calls.sol#16-19) ignores return value by fixed_address.call() (contracts/calls.sol#17)\nCaller.calluseraddress(address) (contracts/calls.sol#21-23) ignores return value by addr.call() (contracts/calls.sol#22)\nCaller.callstoredaddress() (contracts/calls.sol#25-27) ignores return value by stored_address.call() (contracts/calls.sol#26)\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#unchecked-low-level-calls\nINFO:Detectors:\nCaller.constructor(address).addr (contracts/calls.sol#8) lacks a zero-check on :\n\t\t- fixed_address = addr (contracts/calls.sol#9)\nCaller.calluseraddress(address).addr (contracts/calls.sol#21) lacks a zero-check on :\n\t\t- addr.call() (contracts/calls.sol#22)\nCaller.setstoredaddress(address).addr (contracts/calls.sol#29) lacks a zero-check on :\n\t\t- stored_address = addr (contracts/calls.sol#30)\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#missing-zero-address-validation\nINFO:Detectors:\nReentrancy in Caller.reentrancy() (contracts/calls.sol#16-19):\n\tExternal calls:\n\t- fixed_address.call() (contracts/calls.sol#17)\n\tState variables written after the call(s):\n\t- statevar = 0 (contracts/calls.sol#18)\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#reentrancy-vulnerabilities-2\nINFO:Detectors:\nsolc-0.8.2 is not recommended for deployment\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#incorrect-versions-of-solidity\nINFO:Detectors:\nLow level call in Caller.thisisfine() (contracts/calls.sol#12-14):\n\t- fixed_address.call() (contracts/calls.sol#13)\nLow level call in Caller.reentrancy() (contracts/calls.sol#16-19):\n\t- fixed_address.call() (contracts/calls.sol#17)\nLow level call in Caller.calluseraddress(address) (contracts/calls.sol#21-23):\n\t- addr.call() (contracts/calls.sol#22)\nLow level call in Caller.callstoredaddress() (contracts/calls.sol#25-27):\n\t- stored_address.call() (contracts/calls.sol#26)\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#low-level-calls\nINFO:Detectors:\nVariable Caller.fixed_address (contracts/calls.sol#3) is not in mixedCase\nVariable Caller.stored_address (contracts/calls.sol#4) is not in mixedCase\nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#conformance-to-solidity-naming-conventions\nINFO:Detectors:\nCaller.fixed_address (contracts/calls.sol#3) should be immutable \nReference: https://github.com/crytic/slither/wiki/Detector-Documentation#state-variables-that-could-be-declared-immutable\nINFO:Slither:contracts/calls.sol analyzed (1 contracts with 93 detectors), 16 result(s) found\n END, smartcheck: \nruleId: SOLIDITY_CALL_WITHOUT_DATA\npatternId: 111ppp\nseverity: 2\nline: 17\ncolumn: 19\ncontent: call("")\n\nruleId: SOLIDITY_CALL_WITHOUT_DATA\npatternId: 111ppp\nseverity: 2\nline: 22\ncolumn: 10\ncontent: call("")\n\nruleId: SOLIDITY_CALL_WITHOUT_DATA\npatternId: 111ppp\nseverity: 2\nline: 26\ncolumn: 20\ncontent: call("")\n\nruleId: SOLIDITY_UNCHECKED_CALL\npatternId: f39eed\nseverity: 3\nline: 13\ncolumn: 19\ncontent: call("")\n\nruleId: SOLIDITY_UNCHECKED_CALL\npatternId: f39eed\nseverity: 3\nline: 17\ncolumn: 19\ncontent: call("")\n\nruleId: SOLIDITY_UNCHECKED_CALL\npatternId: f39eed\nseverity: 3\nline: 22\ncolumn: 10\ncontent: call("")\n\nruleId: SOLIDITY_UNCHECKED_CALL\npatternId: f39eed\nseverity: 3\nline: 26\ncolumn: 20\ncontent: call("")\n\nruleId: SOLIDITY_VISIBILITY\npatternId: b51ce0\nseverity: 1\nline: 6\ncolumn: 1\ncontent: uint256statevar;\n\nSOLIDITY_VISIBILITY :1\nSOLIDITY_UNCHECKED_CALL :4\nSOLIDITY_CALL_WITHOUT_DATA :4\n END, SOLIDITY_UNCHECKED_CALL :4\n\nThe following code is a comprehensive list of Solidity compiler warnings and errors that are commonly found in Solidity codebase.\n\n1. Solidity compiler warnings and errors are usually caused by incorrect syntax or incorrect Solidity compiler version.\n\n2. Solidity compiler warnings and errors are usually caused by incorrect Solidity compiler version.\n\n3. Solidity compiler warnings and errors are usually caused by incorrect Solidity compiler",
"""})
pprint(output)
# Out:
# [{'generated_text': 'I will provide you with outputs from smart contract '
#                     'frameworks Securify, SmartCheck, Slither and Solhint. '
#                     'Based on the outputs from given contracts, group th\n'
#                     'e common errors among the contracts by meaning and '
#                     'context and return in JSON format as a result '
#                     '{error_name: list_of_frameworks_names} eg. {Incorect '
#                     'solidity version: [solhint, smartcheck], function call w\n'
#                     'ithout data: [slither],}. Take into considerations errors '
#                     'from every framework. Errors should be in human readable '
#                     'form. Sometimes errors have different names but mean the '
#                     'same, handle it, especially smartc\n'
#                     'heck - try to rename them. Frameworks are separated by '
# ...

# %% [markdown]
# Przykład takiego samego zapytania dla modelu gtp-4!
#
#
# ```json
# {"Incorrect Solidity version": ["solhint", "slither"],
#  "Function call without data": ["slither", "smartcheck"],
#  "Function call unchecked": ["slither", "smartcheck"],
#  "Variable not in mixedCase": ["solhint", "slither"],
#  "Visibility not explicitly marked": ["solhint"],
#  "State variables that could be declared immutable": ["slither"],
#  "Avoid usage of low level calls": ["solhint"],
#  "Missing zero-address validation": ["slither"],
#  "Use of deprecated constructor syntax": ["solhint"],
#  "Non-compliance with interface definition": ["solhint"],
#  "Reentrancy vulnerabilities": ["slither"],
#  "Incorrect naming conventions": ["slither"],
#  "State variable should start with _": ["solhint"]}
#
# ```
